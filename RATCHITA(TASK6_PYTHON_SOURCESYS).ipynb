# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 6):
    print(i, end=" ")
# Out:
# 1 2 3 4 5

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i <= 5:
    print(i, end=" ")
    i += 1
# Out:
# 1 2 3 4 5

# %%
total = 0

for i in range(1, 6):
    total += i   
print("Sum =", total)
# Out:
# Sum = 15

# %%
for i in range(1, 6):
    if i == 4:
        break
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(1, 6):
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
text = "SOURCESYS COMPANY"
print(len(text))
# Out:
# 17

# %%
text = "RATCHITA"
print(text[0])   
print(text[3])
# Out:
# R
# C

# %%
text = "HAPPY DAYS"
print(text.lower())
# Out:
# happy days

# %%
text = "happy"
print(text.upper())
# Out:
# HAPPY

# %%
text = "I like programming"
print(text.replace("programming", "Python"))
# Out:
# I like Python

# %%
text = "malayalam"
print(text.count("a"))
# Out:
# 4

# %%
text = "constituition"
print(text[0:4])   # From index 0 to 3
# Out:
# cons

# %%
text = "programming language"
print(text.find("language"))
# Out:
# 12

# %%
text = "   ratchita   "
print(text.strip())
# Out:
# ratchita

# %%
text = "Python"
print(text[::-1])
# Out:
# nohtyP

# %%
name = "RATCHITA"
age = 21

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is RATCHITA and I am 21 years old.

# %%
name = "RATCHU"
age = 21

print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is RATCHU and I am 21 years old.

# %%
print("My name is {0} and I am {1} years old.".format("John", 25))
# Out:
# My name is John and I am 25 years old.

# %%
name = "RATCH"
age = 21

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is RATCH and I am 21 years old.

# %%
name = "A"
age = 22
marks = 89.456

print(f"Name: {name}")
print(f"Age: {age}")
print(f"Marks: {marks:.2f}")
print(f"Next year age: {age + 1}")
